# %%
import py_scheduller

# %%
s = py_scheduller.scheduller()
s.objects.from_xml(open("/Users/wenky/Documents/GitHub/AstroSchedullerGo/tests/psr_list_long.xml").read())
s.get_schedule()
s.plot()
# Out:
# _______       _____
# ___    |________  /_____________
# __  /| |_  ___/  __/_  ___/  __ \
# _  ___ |(__  )/ /_ _  /   / /_/ /
# /_/  |_/____/ \__/ /_/    \____/
#
# ________     ______      _________      ___________
# __  ___/________  /____________  /___  ____  /__  /____________
# _____ \_  ___/_  __ \  _ \  __  /_  / / /_  /__  /_  _ \_  ___/
# ____/ // /__ _  / / /  __/ /_/ / / /_/ /_  / _  / /  __/  /
# /____/ \___/ /_/ /_/\___/\__,_/  \__,_/ /_/  /_/  \___//_/
#
# _________
# __  ____/_____
# _  / __ _  __ \
# / /_/ / / /_/ /
# \____/  \____/
#
# Initializing...INFO:  EOF
# Initializing... Done.
# Scheduling... Done.
# Exporting... Done.
#
# ...
# The schedule has been successfully generated. (v0.9.1 Dev.)
# AstroSchedullerGo is released as an open source project under the MIT license. See https://github.com/xiawenke/AstroSchedullerGo for more information.
#
# Completed:  0.000522 sec.
# ...

# %%
s.stats()
# Out:
# ========== STATS ==========
# | All Objects: 306
# | Scheduled Objects: 61
# | Unscheduled Objects: 245
# | Observation Duration: 82440
# | Wait Duration: -82554
# | Schedule Rate: 19.93%
# ...
